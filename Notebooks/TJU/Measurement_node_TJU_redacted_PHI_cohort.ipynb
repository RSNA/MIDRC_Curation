# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## Creating measurement TSV for TJU redacted PHI cohort:

# %%
#TJU demographic tables that include test measurements:
directory1 = '/content/drive/MyDrive/TJU_RSNA_RICORD_COVID_positive_demographics_2021-11-02.csv'
directory2 = '/content/drive/MyDrive/RSNA_MIDRC_TJU_ Covid_Negative_Population_V2_fix_deidentified.csv'

#patients in this submission:
directory3 = '/content/case_RSNA_20221206.csv'

#measurements from previous TJU submissions:
directory4 = '/content/CORRECTED_measurement_RSNA_20220812.csv'
directory5 = '/content/CORRECTED_measurement_RSNA_20220819.csv'

# %%
df1 = pd.read_csv(directory1)
df2 = pd.read_csv(directory2)
df3 = pd.read_csv(directory3)

df4 = pd.read_csv(directory4)
df5 = pd.read_csv(directory5)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### Starting with gathering measurements from the TJU positive demographics table. We need to clean up this table so it's useful:

# %% [markdown]
# #### First we need to drop the the rows with null values in the patient-id or covid reported date columns:

# %%
df1 = df1.dropna(subset = ['ANON-PatientID', 'ANON-COVID_REPORTED_DATE'])

# %% [markdown]
# #### We are interested in these specific columns:

# %%
df1 = df1[['ANON-PatientID', 'ANON-COVID_REPORTED_DATE', 'COVID_ORDER_NAME', 'COVID_STATUS']]

# %%
df1.rename(columns={'ANON-COVID_REPORTED_DATE': 'ANON_COVID_REPORTED_DATE', 'COVID_ORDER_NAME': 'ORDER_NAME', 'COVID_STATUS': 'RESULT_VALUE', 'ANON-PatientID':'case_ids'}, inplace=True)

# %% [markdown]
# #### Drop any duplicate measurements:

# %%
df1 = df1.drop_duplicates()
df1
# Out:
#             case_ids ANON_COVID_REPORTED_DATE  \
# 0      514382-005370                10/2/2019
# 1      514382-007424                7/10/2019
# 2      514382-004492                4/18/2016
# 3      514382-011373                 2/1/2012
# 4      514382-003854                7/11/2018
# ...              ...                      ...
# 15660  514382-012584                 9/2/2018
# 15661  514382-007966                 6/2/2013
# 15662  514382-006121                6/21/2013
# 15664  514382-008526                 5/3/2015
# 15665  514382-006421               11/14/2017
#
#                                   ORDER_NAME RESULT_VALUE
# 0                  SARS COV-2 (COVID-19) NAA     POSITIVE
# 1             SARS COV-2 (COVID-19) EXTERNAL     POSITIVE
# 2      SARS COV-2 (COVID-19) + INFLUENZA A/B     POSITIVE
# 3      SARS COV-2 (COVID-19) + INFLUENZA A/B     POSITIVE
# 4                  SARS COV-2 (COVID-19) NAA     POSITIVE
# ...                                      ...          ...
# 15660  SARS COV-2 (COVID-19) + INFLUENZA A/B     POSITIVE
# 15661  SARS COV-2 (COVID-19) + INFLUENZA A/B     POSITIVE
# 15662  SARS COV-2 (COVID-19) + INFLUENZA A/B     POSITIVE
# 15664         SARS COV-2 (COVID-19) EXTERNAL     POSITIVE
# 15665  SARS COV-2 (COVID-19) + INFLUENZA A/B     POSITIVE
#
# [14287 rows x 4 columns]

# %% [markdown]
# #### Converting dates to datetime values:

# %%
df1['ANON_COVID_REPORTED_DATE']= pd.to_datetime(df1['ANON_COVID_REPORTED_DATE'])

# %% [markdown]
# #### Sorting values by patient id and reported date:

# %%
df1 = df1.sort_values(by=['case_ids', 'ANON_COVID_REPORTED_DATE'])

# %%
df1
# Out:
#             case_ids ANON_COVID_REPORTED_DATE  \
# 3863   514382-000001               2011-01-05
# 1754   514382-000002               2011-02-05
# 1760   514382-000003               2012-03-22
# 3284   514382-000004               2017-10-22
# 10016  514382-000005               2017-11-27
# ...              ...                      ...
# 12507  514382-014307               2013-07-21
# 11034  514382-014308               2015-01-29
# 14000  514382-014309               2013-11-15
# 5739   514382-014310               2017-11-25
# 10489  514382-014311               2014-03-20
#
#                                               ORDER_NAME RESULT_VALUE
# 3863                           SARS COV-2 (COVID-19) NAA     POSITIVE
# 1754                   SARS COV-2 (COVID-19) (INPATIENT)     POSITIVE
# 1760                           SARS COV-2 (COVID-19) NAA     POSITIVE
# 3284                   SARS COV-2 (COVID-19) (INPATIENT)     POSITIVE
# 10016                                                NaN     POSITIVE
# ...                                                  ...          ...
# 12507                                                NaN     POSITIVE
# 11034              SARS COV-2 (COVID-19) + INFLUENZA A/B     POSITIVE
# 14000                                                NaN     POSITIVE
# 5739   SARS COV-2 (COVID-19) WITH INFLUENZA A, INFLUE...     POSITIVE
# 10489  SARS COV-2 (COVID-19) WITH INFLUENZA A, INFLUE...     POSITIVE
#
# [14287 rows x 4 columns]

# %% [markdown]
# #### Mapping order name values to accepted MIDRC data model values:

# %%
df1['ORDER_NAME'].unique()
# Out:
# array(['SARS COV-2 (COVID-19) NAA', 'SARS COV-2 (COVID-19) (INPATIENT)',
#        nan, 'SARS COV-2 (COVID-19) NJ STATE (LAB USE ONLY)',
#        'SARS COV-2 (COVID-19) (LABCORP)',
#        'TJU SARS COV-2 (LAB ORDER ONLY)',
#        'SARS CORONAVIRUS WITH COV-2 RNA, QUAL RT-PCR (QUEST)',
#        'SARS COV-2 (COVID-19) EXTERNAL',
#        'SARS COV-2 (COVID-19) (EMPLOYEE OR PAT ONLY)',
#        'SARS COV-2 (COVID-19) (JEFFERSON LAB)',
#        'SARS COV-2 (COVID-19) + INFLUENZA A/B',
#        'SARS COV-2 (COVID-19) WITH INFLUENZA A, INFLUENZA B AND RESPIRATORY SYNCYTIAL VIRUS',
#        'SARS COV-2 (COVID-19) NAA - LABCORP / QUEST'], dtype=object)

# %%
df1['ORDER_NAME'] = df1['ORDER_NAME'].map({'SARS COV-2 (COVID-19) NAA': 'RT-PCR', 'SARS COV-2 (COVID-19) (INPATIENT)': 'RT-PCR',
                             'SARS COV-2 (COVID-19) NJ STATE (LAB USE ONLY)': 'RT-PCR',
                             'SARS COV-2 (COVID-19) (LABCORP)': 'RT-PCR',
                             'TJU SARS COV-2 (LAB ORDER ONLY)': 'RT-PCR',
                             'SARS CORONAVIRUS WITH COV-2 RNA, QUAL RT-PCR (QUEST)': 'RT-PCR',
                             'SARS COV-2 (COVID-19) EXTERNAL': 'Not Reported',
                             'SARS COV-2 (COVID-19) (EMPLOYEE OR PAT ONLY)': 'RT-PCR',
                             'SARS COV-2 (COVID-19) (JEFFERSON LAB)': 'RT-PCR',
                             'SARS COV-2 (COVID-19) + INFLUENZA A/B': 'RT-PCR',
                             'SARS COV-2 (COVID-19) WITH INFLUENZA A, INFLUENZA B AND RESPIRATORY SYNCYTIAL VIRUS': 'RT-PCR',
                             'SARS COV-2 (COVID-19) NAA - LABCORP / QUEST': 'RT-PCR'})

# %%
df1['ORDER_NAME'].fillna('Not Reported', inplace = True)

# %%
df1['ORDER_NAME'].unique()
# Out:
# array(['RT-PCR', 'Not Reported'], dtype=object)

# %% [markdown]
# #### Mapping result values to accepted MIDRC data model values:

# %%
df1['RESULT_VALUE'].unique()
# Out:
# array(['POSITIVE'], dtype=object)

# %%
df1['RESULT_VALUE'] = df1['RESULT_VALUE'].map({'POSITIVE': 'Positive'})

# %% [markdown]
# #### The table for positive measurements looks good now:

# %%
df1
# Out:
#             case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE
# 3863   514382-000001               2011-01-05        RT-PCR     Positive
# 1754   514382-000002               2011-02-05        RT-PCR     Positive
# 1760   514382-000003               2012-03-22        RT-PCR     Positive
# 3284   514382-000004               2017-10-22        RT-PCR     Positive
# 10016  514382-000005               2017-11-27  Not Reported     Positive
# ...              ...                      ...           ...          ...
# 12507  514382-014307               2013-07-21  Not Reported     Positive
# 11034  514382-014308               2015-01-29        RT-PCR     Positive
# 14000  514382-014309               2013-11-15  Not Reported     Positive
# 5739   514382-014310               2017-11-25        RT-PCR     Positive
# 10489  514382-014311               2014-03-20        RT-PCR     Positive
#
# [14287 rows x 4 columns]

# %% [markdown]
# ### Onto the TJU negative demographics table. Similarly, we need to also clean up this table so it's useful:

# %%
df2
# Out:
#       ANON-PatientID  Age Gender Desc    ZIP                  Race Desc  \
# 0      514382-000002   82        Male    191                      asian
# 1      514382-000002   82        Male    191                      asian
# 2      514382-000002   82        Male    191                      asian
# 3      514382-000014   54        Male     80  black or african american
# 4      514382-000015   79      Female     80                      asian
# ...              ...  ...         ...    ...                        ...
# 70217  514382-063591   57        Male  191.0  black or african american
# 70218  514382-063592   87        Male  191.0         white or caucasian
# 70219  514382-063593   84        Male  191.0                   hispanic
# 70220  514382-063594   56      Female  191.0         white or caucasian
# 70221  514382-063595   85        Male  191.0         white or caucasian
#
#                                   Ethnicity Desc ANON_ENC_TIMESTAMP  \
# 0      Not Hispanic, Latino/a, or Spanish origin           1/5/2012
# 1      Not Hispanic, Latino/a, or Spanish origin          5/29/2011
# 2      Not Hispanic, Latino/a, or Spanish origin           6/8/2011
# 3      Not Hispanic, Latino/a, or Spanish origin           7/7/2018
# 4      Not Hispanic, Latino/a, or Spanish origin           3/2/2012
# ...                                          ...                ...
# 70217  Not Hispanic, Latino/a, or Spanish origin          3/10/2020
# 70218  Not Hispanic, Latino/a, or Spanish origin           9/5/2014
# 70219                               Puerto Rican           1/8/2015
# 70220  Not Hispanic, Latino/a, or Spanish origin          5/17/2018
# 70221  Not Hispanic, Latino/a, or Spanish origin          9/14/2016
#
#       ANON_ADMISSION_TIMESTAMP                       ORDER_NAME  \
# 0                     1/5/2012        SARS COV-2 (COVID-19) NAA
# 1                    5/29/2011        SARS COV-2 (COVID-19) NAA
# 2                     6/8/2011        SARS COV-2 (COVID-19) NAA
# 3                          NaN  SARS COV-2 (COVID-19) (LABCORP)
# 4                     3/2/2012        SARS COV-2 (COVID-19) NAA
# ...                        ...                              ...
# 70217                3/10/2020        SARS COV-2 (COVID-19) NAA
# 70218                 9/5/2014        SARS COV-2 (COVID-19) NAA
# 70219                 1/8/2015        SARS COV-2 (COVID-19) NAA
# 70220                5/17/2018   SARS COV-2 (COVID-19) EXTERNAL
# 70221                9/14/2016        SARS COV-2 (COVID-19) NAA
#
#       ANON_ORDER_TIMESTAMP  RESULT_VALUE ANON_COVID_REPORTED_DATE  HOSP_LOS  \
# 0                 1/5/2012      Negative                 1/5/2012       1.0
# 1                5/29/2011      Negative                5/30/2011       1.0
# 2                 6/8/2011      Negative                 6/8/2011       5.0
# 3                 7/7/2018  Not Detected                7/10/2018       NaN
# 4                 3/4/2012      Negative                 3/5/2012       7.0
# ...                    ...           ...                      ...       ...
# 70217            3/24/2020      Negative                3/24/2020      18.0
# 70218            9/10/2014      Negative                9/10/2014       5.0
# 70219             1/9/2015      Negative                1/12/2015       4.0
# 70220            5/19/2018     Negative                 5/17/2018       6.0
# 70221            9/20/2016      Negative                9/20/2016       7.0
#
#       HOSP_ENCTR_IND ICU_ENCTR_IND  ICU_DAYS_TOTAL VENT_YN  VENT_DAYS_TOTAL  \
# 0                  Y             N             NaN       N              NaN
# 1                  Y             N             NaN       N              NaN
# 2                  Y             N             NaN       N              NaN
# 3                  N             N             NaN       N              NaN
# 4                  Y             N             NaN       N              NaN
# ...              ...           ...             ...     ...              ...
# 70217              Y             Y            3.16       N              NaN
# 70218              Y             N             NaN       N              NaN
# 70219              Y             N             NaN       N              NaN
# 70220              Y             N             NaN       N              NaN
# 70221              Y             N             NaN       N              NaN
#
#                                    DISCHARGE_DISPOSITION MORTALITY_FLAG
# 0      DISCHARGED TO HOME OR SELF CARE (ROUTINE DISCH...             No
# 1      DISCHARGED TO HOME OR SELF CARE (ROUTINE DISCH...             No
# 2      DISCHARGED/TRANSFERRED TO HOME UNDER CARE OF O...             No
# 3                                                    NaN            NaN
# 4      DISCHARGED/TRANSFERRED TO SKILLED NURSING FACI...             No
# ...                                                  ...            ...
# 70217  DISCHARGED/TRANSFERRED TO HOME UNDER CARE OF O...             No
# 70218  DISCHARGED/TRANSFERRED TO SKILLED NURSING FACI...             No
# 70219  DISCHARGED/TRANSFERRED TO HOME UNDER CARE OF O...             No
# 70220  DISCHARGED TO HOME OR SELF CARE (ROUTINE DISCH...             No
# 70221  DISCHARGED/TRANSFERRED TO SKILLED NURSING FACI...             No
#
# [70222 rows x 20 columns]

# %%
df2 = df2.dropna(subset = ['ANON-PatientID', 'ANON_COVID_REPORTED_DATE'])

# %%
df2 = df2[['ANON-PatientID', 'ANON_COVID_REPORTED_DATE', 'ORDER_NAME', 'RESULT_VALUE']]

# %%
df2 = df2.drop_duplicates()
df2
# Out:
#       ANON-PatientID ANON_COVID_REPORTED_DATE  \
# 0      514382-000002                 1/5/2012
# 1      514382-000002                5/30/2011
# 2      514382-000002                 6/8/2011
# 3      514382-000014                7/10/2018
# 4      514382-000015                 3/5/2012
# ...              ...                      ...
# 70217  514382-063591                3/24/2020
# 70218  514382-063592                9/10/2014
# 70219  514382-063593                1/12/2015
# 70220  514382-063594                5/17/2018
# 70221  514382-063595                9/20/2016
#
#                             ORDER_NAME  RESULT_VALUE
# 0            SARS COV-2 (COVID-19) NAA      Negative
# 1            SARS COV-2 (COVID-19) NAA      Negative
# 2            SARS COV-2 (COVID-19) NAA      Negative
# 3      SARS COV-2 (COVID-19) (LABCORP)  Not Detected
# 4            SARS COV-2 (COVID-19) NAA      Negative
# ...                                ...           ...
# 70217        SARS COV-2 (COVID-19) NAA      Negative
# 70218        SARS COV-2 (COVID-19) NAA      Negative
# 70219        SARS COV-2 (COVID-19) NAA      Negative
# 70220   SARS COV-2 (COVID-19) EXTERNAL     Negative
# 70221        SARS COV-2 (COVID-19) NAA      Negative
#
# [70086 rows x 4 columns]

# %%
dict_rename = {'ANON-PatientID':'case_ids'}
df2.rename(columns=dict_rename,
          inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df2['ANON_COVID_REPORTED_DATE']= pd.to_datetime(df2['ANON_COVID_REPORTED_DATE'])

# %%
df2 = df2.sort_values(by=['case_ids', 'ANON_COVID_REPORTED_DATE'])

# %%
df2
# Out:
#             case_ids ANON_COVID_REPORTED_DATE  \
# 1      514382-000002               2011-05-30
# 2      514382-000002               2011-06-08
# 0      514382-000002               2012-01-05
# 3      514382-000014               2018-07-10
# 4      514382-000015               2012-03-05
# ...              ...                      ...
# 70217  514382-063591               2020-03-24
# 70218  514382-063592               2014-09-10
# 70219  514382-063593               2015-01-12
# 70220  514382-063594               2018-05-17
# 70221  514382-063595               2016-09-20
#
#                             ORDER_NAME  RESULT_VALUE
# 1            SARS COV-2 (COVID-19) NAA      Negative
# 2            SARS COV-2 (COVID-19) NAA      Negative
# 0            SARS COV-2 (COVID-19) NAA      Negative
# 3      SARS COV-2 (COVID-19) (LABCORP)  Not Detected
# 4            SARS COV-2 (COVID-19) NAA      Negative
# ...                                ...           ...
# 70217        SARS COV-2 (COVID-19) NAA      Negative
# 70218        SARS COV-2 (COVID-19) NAA      Negative
# 70219        SARS COV-2 (COVID-19) NAA      Negative
# 70220   SARS COV-2 (COVID-19) EXTERNAL     Negative
# 70221        SARS COV-2 (COVID-19) NAA      Negative
#
# [70086 rows x 4 columns]

# %%
df2['ORDER_NAME'].unique()
# Out:
# array(['SARS COV-2 (COVID-19) NAA', 'SARS COV-2 (COVID-19) (LABCORP)',
#        'SARS COV-2 (COVID-19) EXTERNAL',
#        'SARS COV-2 (COVID-19) (JEFFERSON LAB)',
#        'SARS COV-2 (COVID-19) NJ STATE (LAB USE ONLY)',
#        'SARS COV-2 (LAB ORDER ONLY)',
#        'SARS CORONAVIRUS WITH COV-2 RNA, QUAL RT-PCR (QUEST)'],
#       dtype=object)

# %%
df2['ORDER_NAME'] = df2['ORDER_NAME'].map({'SARS COV-2 (COVID-19) NAA': 'RT-PCR',
                                                       'SARS COV-2 (COVID-19) (LABCORP)': 'RT-PCR',
                                                       'SARS COV-2 (COVID-19) EXTERNAL': 'Not Reported',
                                                       'SARS COV-2 (COVID-19) (JEFFERSON LAB)': 'RT-PCR',
                                                       'SARS COV-2 (COVID-19) NJ STATE (LAB USE ONLY)': 'RT-PCR',
                                                       'SARS COV-2 (LAB ORDER ONLY)': 'RT-PCR',
                                                       'SARS CORONAVIRUS WITH COV-2 RNA, QUAL RT-PCR (QUEST)': 'RT-PCR'})

# %%
df2['ORDER_NAME'].fillna('Not Reported', inplace = True)

# %%
df2['ORDER_NAME'].unique()
# Out:
# array(['RT-PCR', 'Not Reported'], dtype=object)

# %%
df2['RESULT_VALUE'].unique()
# Out:
# array(['Negative', 'Not Detected', 'Negative ', 'NOT DETECTED', 'ik'],
#       dtype=object)

# %%
df2['RESULT_VALUE'] = df2['RESULT_VALUE'].map({'Negative ': 'Negative', 'Not Detected': 'Negative',
                                               'NOT DETECTED': 'Negative', 'ik': 'Not Reported',
                                               'Negative': 'Negative'})

# %%
df2['RESULT_VALUE'].unique()
# Out:
# array(['Negative', 'Not Reported'], dtype=object)

# %% [markdown]
# #### The neagtive measurements table is now ready:

# %%
df2
# Out:
#             case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE
# 1      514382-000002               2011-05-30        RT-PCR     Negative
# 2      514382-000002               2011-06-08        RT-PCR     Negative
# 0      514382-000002               2012-01-05        RT-PCR     Negative
# 3      514382-000014               2018-07-10        RT-PCR     Negative
# 4      514382-000015               2012-03-05        RT-PCR     Negative
# ...              ...                      ...           ...          ...
# 70217  514382-063591               2020-03-24        RT-PCR     Negative
# 70218  514382-063592               2014-09-10        RT-PCR     Negative
# 70219  514382-063593               2015-01-12        RT-PCR     Negative
# 70220  514382-063594               2018-05-17  Not Reported     Negative
# 70221  514382-063595               2016-09-20        RT-PCR     Negative
#
# [70086 rows x 4 columns]

# %% [markdown]
# ### Appending both measurement tables (positive and negative) to gather all measurements:

# %%
all_measurements = df1.append(df2)

# %%
all_measurements
# Out:
#             case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE
# 3863   514382-000001               2011-01-05        RT-PCR     Positive
# 1754   514382-000002               2011-02-05        RT-PCR     Positive
# 1760   514382-000003               2012-03-22        RT-PCR     Positive
# 3284   514382-000004               2017-10-22        RT-PCR     Positive
# 10016  514382-000005               2017-11-27  Not Reported     Positive
# ...              ...                      ...           ...          ...
# 70217  514382-063591               2020-03-24        RT-PCR     Negative
# 70218  514382-063592               2014-09-10        RT-PCR     Negative
# 70219  514382-063593               2015-01-12        RT-PCR     Negative
# 70220  514382-063594               2018-05-17  Not Reported     Negative
# 70221  514382-063595               2016-09-20        RT-PCR     Negative
#
# [84373 rows x 4 columns]

# %% [markdown]
# ### We will use the case node table, df3, to gather the measurements from all the patients in the cohort:

# %%
df3
# Out:
#       type   submitter_id  site_id       case_ids age_at_index_gt89  \
# 0      NaN  514382-000004   514382  514382-000004                No
# 1      NaN  514382-000005   514382  514382-000005                No
# 2      NaN  514382-000007   514382  514382-000007                No
# 3      NaN  514382-000008   514382  514382-000008                No
# 4      NaN  514382-000015   514382  514382-000015                No
# ...    ...            ...      ...            ...               ...
# 2860   NaN  514382-041489   514382  514382-041489                No
# 2861   NaN  514382-041517   514382  514382-041517                No
# 2862   NaN  514382-041532   514382  514382-041532                No
# 2863   NaN  514382-041548   514382  514382-041548                No
# 2864   NaN  514382-041549   514382  514382-041549                No
#
#       age_at_index     sex                       race               ethnicity  \
# 0             68.0    Male                      White  Not Hispanic or Latino
# 1             80.0    Male                      Asian  Not Hispanic or Latino
# 2             63.0  Female  Black or African American  Not Hispanic or Latino
# 3             85.0    Male                      Asian  Not Hispanic or Latino
# 4             79.0  Female                      Asian  Not Hispanic or Latino
# ...            ...     ...                        ...                     ...
# 2860          26.0    Male                      White  Not Hispanic or Latino
# 2861          76.0  Female                      White  Not Hispanic or Latino
# 2862          70.0    Male                      White            Not Reported
# 2863          50.0    Male  Black or African American  Not Hispanic or Latino
# 2864          56.0    Male  Black or African American  Not Hispanic or Latino
#
#       gen3_linked_subjects_available  zip    index_event  \
# 0                                  0   80  COVID-19 Test
# 1                                  0   80  COVID-19 Test
# 2                                  0   81  COVID-19 Test
# 3                                  0   80  COVID-19 Test
# 4                                  0   80  COVID-19 Test
# ...                              ...  ...            ...
# 2860                               0   81  COVID-19 Test
# 2861                               0   81  COVID-19 Test
# 2862                               0   80  COVID-19 Test
# 2863                               0   80  COVID-19 Test
# 2864                               0  191  COVID-19 Test
#
#       linked_external_data covid19_positive  icu_indicator  \
# 0                      NaN              Yes           True
# 1                      NaN              Yes           True
# 2                      NaN              Yes           True
# 3                      NaN              Yes          False
# 4                      NaN               No          False
# ...                    ...              ...            ...
# 2860                   NaN               No          False
# 2861                   NaN               No           True
# 2862                   NaN               No          False
# 2863                   NaN               No          False
# 2864                   NaN               No          False
#
#       ventilator_indicator  country_of_origin  token_record_id  \
# 0                    False                NaN              NaN
# 1                    False                NaN              NaN
# 2                     True                NaN              NaN
# 3                    False                NaN              NaN
# 4                    False                NaN              NaN
# ...                    ...                ...              ...
# 2860                 False                NaN              NaN
# 2861                  True                NaN              NaN
# 2862                 False                NaN              NaN
# 2863                 False                NaN              NaN
# 2864                 False                NaN              NaN
#
#       treatment_info  datasets
# 0                NaN       NaN
# 1                NaN       NaN
# 2                NaN       NaN
# 3                NaN       NaN
# 4                NaN       NaN
# ...              ...       ...
# 2860             NaN       NaN
# 2861             NaN       NaN
# 2862             NaN       NaN
# 2863             NaN       NaN
# 2864             NaN       NaN
#
# [2865 rows x 20 columns]

# %% [markdown]
# #### Gather the subset of measurements that belong only to the patients in this batch:

# %%
sub_measurements = all_measurements.loc[all_measurements.case_ids.isin(df3['case_ids'])]

# %%
sub_measurements
# Out:
#             case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE
# 3284   514382-000004               2017-10-22        RT-PCR     Positive
# 10016  514382-000005               2017-11-27  Not Reported     Positive
# 4201   514382-000007               2018-06-01        RT-PCR     Positive
# 5001   514382-000008               2010-06-03        RT-PCR     Positive
# 9765   514382-000015               2011-04-09        RT-PCR     Positive
# ...              ...                      ...           ...          ...
# 45287  514382-041517               2019-08-30        RT-PCR     Negative
# 45310  514382-041532               2020-10-03        RT-PCR     Negative
# 45329  514382-041548               2014-07-27        RT-PCR     Negative
# 45330  514382-041549               2015-09-20        RT-PCR     Negative
# 45331  514382-041549               2015-12-13        RT-PCR     Negative
#
# [3877 rows x 4 columns]

# %% [markdown]
# #### Sanity check: Make sure that there exists at least one measurement for each patient in the cohort:

# %%
sub_measurements.drop_duplicates(subset = 'case_ids')
# Out:
#             case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE
# 3284   514382-000004               2017-10-22        RT-PCR     Positive
# 10016  514382-000005               2017-11-27  Not Reported     Positive
# 4201   514382-000007               2018-06-01        RT-PCR     Positive
# 5001   514382-000008               2010-06-03        RT-PCR     Positive
# 9765   514382-000015               2011-04-09        RT-PCR     Positive
# ...              ...                      ...           ...          ...
# 45245  514382-041489               2013-12-16        RT-PCR     Negative
# 45287  514382-041517               2019-08-30        RT-PCR     Negative
# 45310  514382-041532               2020-10-03        RT-PCR     Negative
# 45329  514382-041548               2014-07-27        RT-PCR     Negative
# 45330  514382-041549               2015-09-20        RT-PCR     Negative
#
# [2865 rows x 4 columns]

# %% [markdown]
# #### Make sure that the dates are all converted to datetime:

# %%
sub_measurements['ANON_COVID_REPORTED_DATE']= pd.to_datetime(sub_measurements['ANON_COVID_REPORTED_DATE'])
# Out:
# <ipython-input-40-3e08af4189e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub_measurements['ANON_COVID_REPORTED_DATE']= pd.to_datetime(sub_measurements['ANON_COVID_REPORTED_DATE'])

# %% [markdown]
# #### Sort all rows again by patient id and covid reported date:

# %%
sub_measurements = sub_measurements.sort_values(by=['case_ids', 'ANON_COVID_REPORTED_DATE'])

# %%
sub_measurements
# Out:
#             case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE
# 3284   514382-000004               2017-10-22        RT-PCR     Positive
# 10016  514382-000005               2017-11-27  Not Reported     Positive
# 4201   514382-000007               2018-06-01        RT-PCR     Positive
# 5001   514382-000008               2010-06-03        RT-PCR     Positive
# 9765   514382-000015               2011-04-09        RT-PCR     Positive
# ...              ...                      ...           ...          ...
# 45287  514382-041517               2019-08-30        RT-PCR     Negative
# 45310  514382-041532               2020-10-03        RT-PCR     Negative
# 45329  514382-041548               2014-07-27        RT-PCR     Negative
# 45330  514382-041549               2015-09-20        RT-PCR     Negative
# 45331  514382-041549               2015-12-13        RT-PCR     Negative
#
# [3877 rows x 4 columns]

# %% [markdown]
# #### Create submitter_ids in the format Measurement_patient-id_0measurement-count:

# %%
mrns = sub_measurements['case_ids'].tolist()
print(mrns)
# Out:
# ['514382-000004', '514382-000005', '514382-000007', '514382-000008', '514382-000015', '514382-000015', '514382-000018', '514382-000021', '514382-000035', '514382-000043', '514382-000044', '514382-000051', '514382-000057', '514382-000057', '514382-000064', '514382-000067', '514382-000079', '514382-000083', '514382-000087', '514382-000089', '514382-000091', '514382-000099', '514382-000101', '514382-000114', '514382-000121', '514382-000124', '514382-000132', '514382-000133', '514382-000138', '514382-000138', '514382-000138', '514382-000155', '514382-000156', '514382-000164', '514382-000165', '514382-000171', '514382-000171', '514382-000179', '514382-000179', '514382-000188', '514382-000189', '514382-000193', '514382-000198', '514382-000201', '514382-000211', '514382-000221', '514382-000225', '514382-000247', '514382-000250', '514382-000254', '514382-000258', '514382-000261', '514382-000268', '514382-000270', '514382-000271', '514382-000271', '514382-000271', '514382-000274', '514382-000287', '514382-000289', '514382-000292', '514382-000292', '514382-000294', '514382-000300', '514382-000304', '514382-000304', '514382-000319', '514382-000325', '514382-000331', '514382-000332', '514382-000332', '514382-000335', '514382-000336', '514382-000344', '514382-000344', '514382-000359', '514382-000361', '514382-000375', '514382-000375', '514382-000383', '514382-000384', '514382-000388', '514382-000388', '514382-000388', '514382-000393', '514382-000394', '514382-000396', '514382-000430', '514382-000433', '514382-000436', '514382-000438', '514382-000441', '514382-000444', '514382-000445', '514382-000446', '514382-000448', '514382-000453', '514382-000455', '514382-000463', '514382-000463', '514382-000463', '514382-000466', '514382-000468', '514382-000479', '514382-000483', '514382-000484', '514382-000485', '514382-000487', '514382-000487', '514382-000505', '514382-000510', '514382-000515', '514382-000517', '514382-000519', '514382-000519', '514382-000523', '514382-000524', '514382-000525', '514382-000532', '514382-000544', '514382-000548', '514382-000556', '514382-000556', '514382-000556', '514382-000556', '514382-000574', '514382-000574', '514382-000574', '514382-000576', '514382-000585', '514382-000589', '514382-000610', '514382-000612', '514382-000615', '514382-000619', '514382-000621', '514382-000623', '514382-000625', '514382-000629', '514382-000630', '514382-000630', '514382-000634', '514382-000641', '514382-000641', '514382-000641', '514382-000641', '514382-000641', '514382-000645', '514382-000647', '514382-000647', '514382-000648', '514382-000649', '514382-000650', '514382-000658', '514382-000662', '514382-000672', '514382-000676', '514382-000677', '514382-000687', '514382-000690', '514382-000690', '514382-000690', '514382-000691', '514382-000705', '514382-000705', '514382-000708', '514382-000708', '514382-000708', '514382-000719', '514382-000719', '514382-000720', '514382-000727', '514382-000747', '514382-000753', '514382-000753', '514382-000755', '514382-000755', '514382-000758', '514382-000770', '514382-000772', '514382-000782', '514382-000785', '514382-000788', '514382-000789', '514382-000800', '514382-000816', '514382-000818', '514382-000824', '514382-000828', '514382-000829', '514382-000836', '514382-000848', '514382-000851', '514382-000867', '514382-000867', '514382-000870', '514382-000870', '514382-000870', '514382-000870', '514382-000870', '514382-000876', '514382-000895', '514382-000898', '514382-000899', '514382-000906', '514382-000906', '514382-000906', '514382-000916', '514382-000918', '514382-000920', '514382-000921', '514382-000921', '514382-000922', '514382-000922', '514382-000925', '514382-000926', '514382-000927', '514382-000943', '514382-000947', '514382-000948', '514382-000962', '514382-000964', '514382-000966', '514382-000969', '514382-000970', '514382-000973', '514382-000976', '514382-000979', '514382-000979', '514382-000984', '514382-000984', '514382-000986', '514382-000995', '514382-000995', '514382-000997', '514 ...

# %%
count = 1
for i in range(len(mrns)):
  if i !=(len(mrns)-1):
    next = mrns[i+1]
  else:
    next = 'end'
  current = mrns[i]
  mrns[i] = mrns[i] + "_0" + str(count)
  if current == next:
    count = count+1
  else:
    count = 1

# %%
sub_measurements = sub_measurements.assign(submitter_id=mrns)
sub_measurements
# Out:
#             case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE  \
# 3284   514382-000004               2017-10-22        RT-PCR     Positive
# 10016  514382-000005               2017-11-27  Not Reported     Positive
# 4201   514382-000007               2018-06-01        RT-PCR     Positive
# 5001   514382-000008               2010-06-03        RT-PCR     Positive
# 9765   514382-000015               2011-04-09        RT-PCR     Positive
# ...              ...                      ...           ...          ...
# 45287  514382-041517               2019-08-30        RT-PCR     Negative
# 45310  514382-041532               2020-10-03        RT-PCR     Negative
# 45329  514382-041548               2014-07-27        RT-PCR     Negative
# 45330  514382-041549               2015-09-20        RT-PCR     Negative
# 45331  514382-041549               2015-12-13        RT-PCR     Negative
#
#            submitter_id
# 3284   514382-000004_01
# 10016  514382-000005_01
# 4201   514382-000007_01
# 5001   514382-000008_01
# 9765   514382-000015_01
# ...                 ...
# 45287  514382-041517_01
# 45310  514382-041532_01
# 45329  514382-041548_01
# 45330  514382-041549_01
# 45331  514382-041549_02
#
# [3877 rows x 5 columns]

# %%
sub_measurements["submitter_id"] =   "Measurement_" + sub_measurements["submitter_id"]

# %% [markdown]
# #### Calculate test_days_from_index:

# %%
sub_measurements = sub_measurements.reset_index(drop=True)

# %%
test_days_from_index = []
track = ''
date_time = datetime.date.today()
for ind in sub_measurements.index:
    if sub_measurements['case_ids'][ind] == track:
      test_days_from_index.append((sub_measurements['ANON_COVID_REPORTED_DATE'][ind]-date_time).days)
    else:
      test_days_from_index.append(0)
      date_time = sub_measurements['ANON_COVID_REPORTED_DATE'][ind]
    track = sub_measurements['case_ids'][ind]

# %%
sub_measurements['test_days_from_index'] = test_days_from_index

# %%
sub_measurements
# Out:
#            case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE  \
# 0     514382-000004               2017-10-22        RT-PCR     Positive
# 1     514382-000005               2017-11-27  Not Reported     Positive
# 2     514382-000007               2018-06-01        RT-PCR     Positive
# 3     514382-000008               2010-06-03        RT-PCR     Positive
# 4     514382-000015               2011-04-09        RT-PCR     Positive
# ...             ...                      ...           ...          ...
# 3872  514382-041517               2019-08-30        RT-PCR     Negative
# 3873  514382-041532               2020-10-03        RT-PCR     Negative
# 3874  514382-041548               2014-07-27        RT-PCR     Negative
# 3875  514382-041549               2015-09-20        RT-PCR     Negative
# 3876  514382-041549               2015-12-13        RT-PCR     Negative
#
#                       submitter_id  test_days_from_index
# 0     Measurement_514382-000004_01                     0
# 1     Measurement_514382-000005_01                     0
# 2     Measurement_514382-000007_01                     0
# 3     Measurement_514382-000008_01                     0
# 4     Measurement_514382-000015_01                     0
# ...                            ...                   ...
# 3872  Measurement_514382-041517_01                     0
# 3873  Measurement_514382-041532_01                     0
# 3874  Measurement_514382-041548_01                     0
# 3875  Measurement_514382-041549_01                     0
# 3876  Measurement_514382-041549_02                    84
#
# [3877 rows x 6 columns]

# %% [markdown]
# #### Keep the measurements that weren't submitted in the previous two submissions of TJU data:

# %%
sub_measurements_left = sub_measurements.loc[~sub_measurements.case_ids.isin(df4['case_ids'])]

# %%
sub_measurements_left = sub_measurements_left.loc[~sub_measurements_left.case_ids.isin(df5['case_ids'])]
sub_measurements_left
# Out:
#            case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE  \
# 0     514382-000004               2017-10-22        RT-PCR     Positive
# 1     514382-000005               2017-11-27  Not Reported     Positive
# 3     514382-000008               2010-06-03        RT-PCR     Positive
# 4     514382-000015               2011-04-09        RT-PCR     Positive
# 5     514382-000015               2012-03-05        RT-PCR     Negative
# ...             ...                      ...           ...          ...
# 3872  514382-041517               2019-08-30        RT-PCR     Negative
# 3873  514382-041532               2020-10-03        RT-PCR     Negative
# 3874  514382-041548               2014-07-27        RT-PCR     Negative
# 3875  514382-041549               2015-09-20        RT-PCR     Negative
# 3876  514382-041549               2015-12-13        RT-PCR     Negative
#
#                       submitter_id  test_days_from_index
# 0     Measurement_514382-000004_01                     0
# 1     Measurement_514382-000005_01                     0
# 3     Measurement_514382-000008_01                     0
# 4     Measurement_514382-000015_01                     0
# 5     Measurement_514382-000015_02                   331
# ...                            ...                   ...
# 3872  Measurement_514382-041517_01                     0
# 3873  Measurement_514382-041532_01                     0
# 3874  Measurement_514382-041548_01                     0
# 3875  Measurement_514382-041549_01                     0
# 3876  Measurement_514382-041549_02                    84
#
# [2896 rows x 6 columns]

# %% [markdown]
# #### We're left with 2896 measurements total. Let's make sure that the submitter_ids are unique:

# %%
sub_measurements_left.drop_duplicates(subset = 'submitter_id')
# Out:
#            case_ids ANON_COVID_REPORTED_DATE    ORDER_NAME RESULT_VALUE  \
# 0     514382-000004               2017-10-22        RT-PCR     Positive
# 1     514382-000005               2017-11-27  Not Reported     Positive
# 3     514382-000008               2010-06-03        RT-PCR     Positive
# 4     514382-000015               2011-04-09        RT-PCR     Positive
# 5     514382-000015               2012-03-05        RT-PCR     Negative
# ...             ...                      ...           ...          ...
# 3872  514382-041517               2019-08-30        RT-PCR     Negative
# 3873  514382-041532               2020-10-03        RT-PCR     Negative
# 3874  514382-041548               2014-07-27        RT-PCR     Negative
# 3875  514382-041549               2015-09-20        RT-PCR     Negative
# 3876  514382-041549               2015-12-13        RT-PCR     Negative
#
#                       submitter_id  test_days_from_index
# 0     Measurement_514382-000004_01                     0
# 1     Measurement_514382-000005_01                     0
# 3     Measurement_514382-000008_01                     0
# 4     Measurement_514382-000015_01                     0
# 5     Measurement_514382-000015_02                   331
# ...                            ...                   ...
# 3872  Measurement_514382-041517_01                     0
# 3873  Measurement_514382-041532_01                     0
# 3874  Measurement_514382-041548_01                     0
# 3875  Measurement_514382-041549_01                     0
# 3876  Measurement_514382-041549_02                    84
#
# [2896 rows x 6 columns]

# %% [markdown]
# #### Rename the columns to adhere to the MIDRC data model:

# %%
sub_measurements_left['test_name'] = 'COVID-19'

# %%
sub_measurements_left['cases'] = sub_measurements_left['case_ids']

# %%
dict_rename = {'RESULT_VALUE':'test_result_text',
               'ORDER_NAME': 'test_method'}
sub_measurements_left.rename(columns=dict_rename,
          inplace=True)

# %%
sub_measurements_left
# Out:
#            case_ids ANON_COVID_REPORTED_DATE   test_method test_result_text  \
# 0     514382-000004               2017-10-22        RT-PCR         Positive
# 1     514382-000005               2017-11-27  Not Reported         Positive
# 3     514382-000008               2010-06-03        RT-PCR         Positive
# 4     514382-000015               2011-04-09        RT-PCR         Positive
# 5     514382-000015               2012-03-05        RT-PCR         Negative
# ...             ...                      ...           ...              ...
# 3872  514382-041517               2019-08-30        RT-PCR         Negative
# 3873  514382-041532               2020-10-03        RT-PCR         Negative
# 3874  514382-041548               2014-07-27        RT-PCR         Negative
# 3875  514382-041549               2015-09-20        RT-PCR         Negative
# 3876  514382-041549               2015-12-13        RT-PCR         Negative
#
#                       submitter_id  test_days_from_index test_name  \
# 0     Measurement_514382-000004_01                     0  COVID-19
# 1     Measurement_514382-000005_01                     0  COVID-19
# 3     Measurement_514382-000008_01                     0  COVID-19
# 4     Measurement_514382-000015_01                     0  COVID-19
# 5     Measurement_514382-000015_02                   331  COVID-19
# ...                            ...                   ...       ...
# 3872  Measurement_514382-041517_01                     0  COVID-19
# 3873  Measurement_514382-041532_01                     0  COVID-19
# 3874  Measurement_514382-041548_01                     0  COVID-19
# 3875  Measurement_514382-041549_01                     0  COVID-19
# 3876  Measurement_514382-041549_02                    84  COVID-19
#
#               cases
# 0     514382-000004
# 1     514382-000005
# 3     514382-000008
# 4     514382-000015
# 5     514382-000015
# ...             ...
# 3872  514382-041517
# 3873  514382-041532
# 3874  514382-041548
# 3875  514382-041549
# 3876  514382-041549
#
# [2896 rows x 8 columns]

# %% [markdown]
# #### Save file:

# %%
sub_measurements_left.to_csv('measurement_RSNA_20221206.csv', index = False)
